# %% [markdown]
# # OSMnx features demo
#
# Get street networks anywhere in the world from OpenStreetMap data then analyze and visualize them.
#
# More info:
#
#   - [Documentation and install instructions](https://osmnx.readthedocs.io)
#   - [Examples, demos, tutorials](https://github.com/gboeing/osmnx-examples)
#   - [Journal article and citation info](http://geoffboeing.com/publications/osmnx-complex-street-networks/)

# %%
import networkx as nx
import numpy as np
import geopandas as gpd
import fiona
import osmnx as ox
import requests
import skmob
import pandas as pd
import json
from datetime import datetime
import warnings

warnings.filterwarnings(action='once')
import matplotlib.cm as cm
import matplotlib.colors as colors
ox.config(use_cache=True, log_console=True)
ox.__version__
# Out:
# '0.16.1'

# %%
# get the walking network for piedmont
place = 'Chicago, Illinois, USA'
G = ox.graph_from_place(place, network_type='drive')
fig, ax = ox.plot_graph(G)
# Out:
# C:\Users\chitr\anaconda3\envs\skmob\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# what sized area does our network cover in square meters?
G_proj = ox.project_graph(G)
nodes_proj = ox.graph_to_gdfs(G_proj, edges=False)
graph_area_m = nodes_proj.unary_union.convex_hull.area
graph_area_m
# Out:
# C:\Users\chitr\anaconda3\envs\skmob\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 755005175.7457961

# %% [markdown]
# stats documentation: https://osmnx.readthedocs.io/en/stable/osmnx.html#module-osmnx.stats

# %% [markdown]
# ## Visualize street centrality

# %%
# assign speeds and traversal times to the edges
for u, v, k, d in G.edges(keys=True, data=True):
    if 'residential' in d['highway']:
        d['speed'] = 20
    elif 'tertiary' in d['highway']:
        d['speed'] = 30
    elif 'secondary' in d['highway']:
        d['speed'] = 40
    else:
        d['speed'] = 25
    
    # calculate time to traverse edge, in minutes
    d['time'] = d['length'] / (d['speed'] * 1609.34 / 60) #miles/hour to meters/minute

# %% [markdown]
# ## Importing Crime Data (To be used later)....  for simulating an average crime scenario... Best case, Worst case and Average Crime Rate Data Statistic

# %%
data = pd.read_csv('chicago_crime_median_timestamp.csv')#, sep = " ", names = ['time', 'lon', 'lat'])
data['user_id']=1

# %%
data
# Out:
#                Timestamp   Latitude  Longitude  #Responders  Police  Priority  \
# 0     2014-10-28 0:00:00  41.756902 -87.650269            1       0         2
# 1     2014-10-28 0:00:00  41.871560 -87.703393            1       0         3
# 2     2014-10-28 0:00:00  41.742710 -87.634088            1       0         3
# 3     2014-10-28 0:01:00  41.904385 -87.732190            1       0         3
# 4     2014-10-28 0:01:00  41.891769 -87.622137            1       0         3
# ..                   ...        ...        ...          ...     ...       ...
# 745  2014-10-28 23:45:00  41.760329 -87.574934            1       0         3
# 746  2014-10-28 23:45:00  41.809297 -87.687864            1       0         3
# 747  2014-10-28 23:47:00  41.764249 -87.651669            1       0         2
# 748  2014-10-28 23:50:00  41.801719 -87.630704            1       0         3
# 749  2014-10-28 23:56:00  41.813092 -87.704172            1       0         3
#
#         Service Time  user_id
# 0    0 days 00:20:00        1
# 1    0 days 00:24:00        1
# 2    0 days 00:34:00        1
# 3    0 days 00:24:00        1
# 4    0 days 00:25:00        1
# ..               ...      ...
# 745  0 days 00:30:00        1
# 746  0 days 00:37:00        1
# 747  0 days 00:28:00        1
# 748  0 days 00:23:00        1
# 749  0 days 00:28:00        1
#
# [750 rows x 8 columns]

# %%
crime_data = data[[ 'Timestamp','Latitude', 'Longitude','Priority','Service Time']] 
crime_data.head()
# Out:
# C:\Users\chitr\anaconda3\envs\skmob\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             Timestamp   Latitude  Longitude  Priority     Service Time
# 0  2014-10-28 0:00:00  41.756902 -87.650269         2  0 days 00:20:00
# 1  2014-10-28 0:00:00  41.871560 -87.703393         3  0 days 00:24:00
# 2  2014-10-28 0:00:00  41.742710 -87.634088         3  0 days 00:34:00
# 3  2014-10-28 0:01:00  41.904385 -87.732190         3  0 days 00:24:00
# 4  2014-10-28 0:01:00  41.891769 -87.622137         3  0 days 00:25:00

# %% [markdown]
# ## Importing Police Location Data (Using that as location for police for basic simulation)

# %%
PS_data = pd.read_csv('Police_Stations_-_Map.csv')#, sep = " ", names = ['time', 'lon', 'lat'])
PS_data['user_id']=1

cr_lat=[]
cr_long=[]

for i in range(len(PS_data)):
    s = PS_data['LOCATION'][i]
    s= s[1:-1]
    f = [float(x) for x in s.split(", ")]
    cr_lat.append(f[0])
    cr_long.append(f[1])

PS_data['lat']=cr_lat
PS_data['long']=cr_long
# Out:
# C:\Users\chitr\anaconda3\envs\skmob\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
Gs = ox.utils_graph.get_largest_component(G, strongly=True)

# %%
PC_node=[]

for i in range(len(PS_data)):
    t = (ox.get_nearest_node(Gs, (cr_lat[i], cr_long[i])))
    PC_node.append(t)

# %%
class ndk:
    G=[]
    nodes=[]
    SPL={}
    def calc():
        for i in ndk.nodes:
            ndk.SPL[i]=nx.shortest_path_length(ndk.G, source=i, weight='time')
    def shortest_path_length(G, source, target, weight='none'):
        return ndk.SPL[source][target]
ndk.G=Gs
ndk.nodes=PC_node
ndk.calc()

# %%
def Cloning(li1): 
    li_copy = li1[:] 
    return li_copy

# %%
def column(matrix, i):
    return [row[i] for row in matrix]

# %%
class Police:
    def __init__(self,ID,G,loc,resp,dt):
        self.ID=ID #a unique id
        self.G=G #pointer to the graph the officer travels on (Warning:edits to this graph have global consequences)
        self.loc=loc #the Node that the police officer is at
        self.resp=resp #true if the officer is responding to a crime event, false if patroling
        self.downtime=dt #Remaining time that the police is "down" due to a response event
        self.nodeInd=self.getNodeInd() #the index of the node that the officer is located in list(G.nodes())
    
    #tested
    #Randomly move the officer to an adjacent node if they are not responding
    def walk(self):
        if not(self.resp):
            wk= list(nx.classes.function.all_neighbors(self.G,(list(self.G.nodes)[self.nodeInd])))
            j = np.random.choice(wk)
            self.updateLoc(j)
            
    #moves the police officer toward the node they need to respond to
    def respond(self):
        if self.resp:
            return
    
    #updates the police location (no matter if they are responding or patroling)
    def update(self):
        i.walk()
        i.respond()
        
    #updates the location of the officer to the new Node (and changes the node ID)
    def updateLoc(self,newloc):
        self.loc=newloc
        self.nodeInd=self.getNodeInd()
        
    #gets the index of the node that corresponds to its ID
    def getNodeInd(self):
        return list(self.G.nodes).index(self.loc)

# %%
#initialize police officers as a list of variable from the class "Police"
NumberOfPolice=10
#Pol_loc=np.random.choice(len(G.nodes),size=(1,10),replace=False)
Police_officers=[]
for i in range(len(PC_node)):
    Pol_loc=PC_node[i]
    Police_officers.append(Police(i,G,Pol_loc,False,0))

# %% [markdown]
# ## Evaluating Response time based on the nearest police location to the crime

# %% [markdown]
# ## Initialize varibales : no of police associated with police location, no of police needed based on crime,

# %%
crime_node=[]

for i in range(len(crime_data)):
    t = (ox.get_nearest_node(Gs, (crime_data['Latitude'][i], crime_data['Longitude'][i])))
    crime_node.append(t)

# %%
from datetime import datetime
datetime_object=[]
VG_datetime_object=[]
NVG_datetime_object=[]
#t0 = '2014-08-01 00:00:00'  # worst case day
t0 = '2014-10-28 00:00:00'  # median case day
t_ini = datetime.strptime(t0, '%Y-%m-%d %H:%M:%S')
time_seq=[]
VG_time_seq=[]
NVG_time_seq=[]

srvtime_object=[]
ser_time =[]
s0 ='00:00:00'
ss_ini = datetime.strptime(s0, '%H:%M:%S')

for i in range(len(crime_data)):
    datetime_str = crime_data['Timestamp'][i]
    datetime_object.append(datetime.strptime(datetime_str, '%Y-%m-%d %H:%M:%S'))
    tt = (datetime_object[i]-t_ini).total_seconds()
    time_seq.append(tt)
    
    srvtime_str = crime_data['Service Time'][i]
    srvtime_object.append(datetime.strptime(srvtime_str[7:-1],'%H:%M:%S'))
    ss = (srvtime_object[i]-ss_ini).total_seconds()
    ser_time.append(ss)

# %%
time_min = [x / 60 for x in time_seq]
ser_min = [x / 60 for x in ser_time]
Crime = [time_min,crime_node,ser_min]

# %%
def eva_resp_time(police,Crime,NoOfOfficer):
    Resp_time = []
    orig_node = police
    #ser_time = 1200 # 20 mins service time
    my_array=[]
    arr_crime = [[0 for i in range(2)] for j in range(len(orig_node))]
    my_array = np.array(arr_crime).astype('int64')
    my_array[:,1]= orig_node 
    PC_stalk = [[0 for i in range(9)] for j in range(len(orig_node))] 
    for x in range(len(orig_node)):
        PC_stalk[x][0] =orig_node[x]
    for x in range(len(orig_node)):
        for y in range(3,9):
            PC_stalk[x][y]=[]
    columnIndex = 0   
    for j in range(len(Crime[0])):
        dest_node = Crime[1][j]
        Crime_node = Crime[1][j]
        Crime_time = Crime[0][j] ##chnage this
        Ser_time = Crime[2][j]
        if j !=len(Crime[0])-1:
            Crime_time_next = Crime[0][j+1]  ##change this            
            
        for i in range(len(orig_node)):
            arr = ndk.shortest_path_length(Gs, orig_node[i], Crime_node, weight='time')
            my_array[i,0] = arr
            # Sort 2D numpy array by 1st Column
        sortedArr = my_array[my_array[:,columnIndex].argsort()]
        
        s = sortedArr[0][1]
        idx = np.argwhere(column(PC_stalk, 0) == s)[0][0] 

        if PC_stalk[idx][1] < NoOfOfficer:  # 
                PC_stalk[idx][1]= PC_stalk[idx][1]+1
                PC_stalk[idx][3].append(Crime_time)
                PC_stalk[idx][4].append(Crime_node)
                temp = ndk.shortest_path_length(Gs, PC_stalk[idx][0], Crime_node, weight='time')
                PC_stalk[idx][5].append(2*temp + Crime_time + Ser_time)
                Resp_time.append([temp,Crime_time])

        else : #--> 
       
            PC_stalk[idx][2]= PC_stalk[idx][2]+1
            PC_stalk[idx][6].append(Crime_node)
            PC_stalk[idx][7].append(Crime_time)
            PC_stalk[idx][8].append(Ser_time)
            
            
        if j !=len(Crime[0])-1:
            ## Check if a PC node is going to available
            for idx in range(len(orig_node)):
                y=0
                while (PC_stalk[idx][1])>0 and y<=PC_stalk[idx][1]-1:
                    if PC_stalk[idx][5][y] <= Crime_time_next:
                        if PC_stalk[idx][2]>0:
                            PC_stalk[idx][2]= PC_stalk[idx][2]-1
                            temp1 = PC_stalk[idx][5][y]
                            PC_stalk[idx][3].remove(PC_stalk[idx][3][y])
                            PC_stalk[idx][3].append(temp1)
                            temp2 = PC_stalk[idx][6][0]     ##Change from y to 0
                            PC_stalk[idx][4].remove(PC_stalk[idx][4][y])
                            PC_stalk[idx][4].append(temp2)
                            temp3 = ndk.shortest_path_length(Gs, PC_stalk[idx][0],temp2, weight='time')
                            wait = temp1 - PC_stalk[idx][7][0]
                            se_time = PC_stalk[idx][8][0]
                            PC_stalk[idx][5].remove(PC_stalk[idx][5][y])
                            PC_stalk[idx][5].append(2*temp3 + temp1 + se_time)
                            Resp_time.append([wait+temp3,PC_stalk[idx][7][0]])
                            PC_stalk[idx][6].remove(PC_stalk[idx][6][0])
                            PC_stalk[idx][7].remove(PC_stalk[idx][7][0])
                            PC_stalk[idx][8].remove(PC_stalk[idx][8][0])
                        else:
                            PC_stalk[idx][1]= PC_stalk[idx][1]-1
                            PC_stalk[idx][3].remove(PC_stalk[idx][3][y])
                            PC_stalk[idx][4].remove(PC_stalk[idx][4][y])
                            PC_stalk[idx][5].remove(PC_stalk[idx][5][y])
                    else:
                        y=y+1
    d=[]
    for idx in range(len(orig_node)):
        while PC_stalk[idx][2]>0:
            a = min(PC_stalk[idx][5])
            ind = PC_stalk[idx][5].index(a)
            PC_stalk[idx][2]= PC_stalk[idx][2]-1
            temp1 = PC_stalk[idx][5][ind]
            PC_stalk[idx][3].remove(PC_stalk[idx][3][ind])
            PC_stalk[idx][3].append(temp1)
            temp2 = PC_stalk[idx][6][0]
            PC_stalk[idx][4].remove(PC_stalk[idx][4][ind])
            PC_stalk[idx][4].append(temp2)
            temp3 = ndk.shortest_path_length(Gs, PC_stalk[idx][0],temp2, weight='time')
            wait = temp1 - PC_stalk[idx][7][0]
            ser_time = PC_stalk[idx][8][0]
            PC_stalk[idx][5].remove(PC_stalk[idx][5][ind])
            PC_stalk[idx][5].append(2*temp3 + temp1 + ser_time)
            d.append([wait+temp3,PC_stalk[idx][7][0]])
            PC_stalk[idx][6].remove(PC_stalk[idx][6][0])
            PC_stalk[idx][7].remove(PC_stalk[idx][7][0])
            PC_stalk[idx][8].remove(PC_stalk[idx][8][0])
    Resp_time.extend(d)
    return Resp_time

# %%
police = PC_node

NoOfPolice = 2;    #### Change no of police here

# %%
Resp_time = eva_resp_time(police,Crime,NoOfPolice)

# %%
import matplotlib.pyplot as plt

res_time = column(Resp_time, 0)

plt.hist(res_time)
plt.ylabel('Frequency')
plt.xlabel('Response Time [min]')
plt.title("Histogram :" + str(NoOfPolice) + " police officers per station");
 
plt.show()

# %%
import statistics

print('The median with ' + str(NoOfPolice) + ' officers per station is ', statistics.median(res_time))
avg1 = sum(res_time)/len(res_time)
print('The average with ' + str(NoOfPolice) + ' officers per station is ', round(avg1,2))
print('The max response time with ' + str(NoOfPolice) + ' officers per station is ', max(res_time))
# Out:
# The median with 2 officers per station is  3.250106845042068
# The average with 2 officers per station is  10.65
# The max response time with 2 officers per station is  115.09847322504893

# %% [markdown]
# ## Police Beats

# %%
import fiona
from shapely.geometry import shape,mapping, Point, Polygon, MultiPolygon
multipol = fiona.open("Chicago_PB.shp")
multi= multipol.next()
# Out:
# C:\Users\chitr\anaconda3\envs\skmob\lib\site-packages\ipykernel_launcher.py:4: FionaDeprecationWarning: Collection.__next__() is buggy and will be removed in Fiona 2.0. Switch to `next(iter(collection))`.
#   after removing the cwd from sys.path.

# %%
fp = "Chicago_PB.shp"
polys  = gpd.read_file(fp)

# %%
southern = polys[polys['dist_num']=='1']
poly = southern['geometry']

# %%
geometry =[Point (xy) for xy in zip(PS_data['long'],PS_data['lat'])]

# %%
geo_df = gpd.GeoDataFrame(PS_data,geometry = geometry)

# %%
fig, ax = plt.subplots()

polys.plot(ax=ax, facecolor='gray');
southern.plot(ax=ax, facecolor='red');
geo_df[geo_df['DISTRICT'] == '1'].plot(ax=ax, color='blue', markersize=5)
# Out:
# <AxesSubplot:>

# %%
PS_data
# Out:
# C:\Users\chitr\anaconda3\envs\skmob\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         DISTRICT                   ADDRESS     CITY STATE    ZIP  \
# 0              1           1718 S State St  Chicago    IL  60616
# 1              6         7808 S Halsted St  Chicago    IL  60620
# 2             11        3151 W Harrison St  Chicago    IL  60612
# 3             16      5151 N Milwaukee Ave  Chicago    IL  60630
# 4   Headquarters       3510 S Michigan Ave  Chicago    IL  60653
# 5             24           6464 N Clark St  Chicago    IL  60626
# 6              2      5101 S Wentworth Ave  Chicago    IL  60609
# 7              7            1438 W 63rd St  Chicago    IL  60636
# 8             25          5555 W Grand Ave  Chicago    IL  60639
# 9             10          3315 W Ogden Ave  Chicago    IL  60623
# 10            15         5701 W Madison St  Chicago    IL  60644
# 11             3  7040 S Cottage Grove Ave  Chicago    IL  60637
# 12            14     2150 N California Ave  Chicago    IL  60647
# 13             8            3420 W 63rd St  Chicago    IL  60629
# 14             4           2255 E 103rd St  Chicago    IL  60617
# 15            20        5400 N Lincoln Ave  Chicago    IL  60625
# 16            18        1160 N Larrabee St  Chicago    IL  60610
# 17            12  1412 S Blue Island Ave\n  Chicago    IL  60608
# 18             9         3120 S Halsted St  Chicago    IL  60608
# 19            22       1900 W Monterey Ave  Chicago    IL  60643
# 20             5            727 E 111th St  Chicago    IL  60628
# 21            17         4650 N Pulaski Rd  Chicago    IL  60630
# 22            19          850 W Addison St  Chicago    IL  60613
#
#                                               WEBSITE  \
# 0   http://home.chicagopolice.org/community/distri...
# 1   http://home.chicagopolice.org/community/distri...
# 2   http://home.chicagopolice.org/community/distri...
# 3   http://home.chicagopolice.org/community/distri...
# 4                       http://home.chicagopolice.org
# 5   http://home.chicagopolice.org/community/distri...
# 6   http://home.chicagopolice.org/community/distri...
# 7   http://home.chicagopolice.org/community/distri...
# 8   http://home.chicagopolice.org/community/distri...
# 9   http://home.chicagopolice.org/community/distri...
# 10  http://home.chicagopolice.org/community/distri...
# 11  http://home.chicagopolice.org/community/distri...
# 12  http://home.chicagopolice.org/community/distri...
# 13  http://home.chicagopolice.org/community/distri...
# 14  http://home.chicagopolice.org/community/distri...
# 15  http://home.chicagopolice.org/community/distri...
# 16  http://home.chicagopolice.org/community/distri...
# 17  http://home.chicagopolice.org/community/distri...
# 18  http://home.chicagopolice.org/community/distri...
# 19  http://home.chicagopolice.org/community/distri...
# 20  http://home.chicagopolice.org/community/distri...
# 21  http://home.chicagopolice.org/community/distri...
# 22  http://home.chicagopolice.org/community/distri...
#
#                            LOCATION  user_id        lat       long  \
# 0    (41.8583725929, -87.627356171)        1  41.858373 -87.627356
# 1   (41.7521368378, -87.6442289066)        1  41.752137 -87.644229
# 2    (41.8735822883, -87.705488126)        1  41.873582 -87.705488
# 3   (41.9740944511, -87.7661488432)        1  41.974094 -87.766149
# 4   (41.8307016873, -87.6233953459)        1  41.830702 -87.623395
# 5   (41.9997634842, -87.6713242922)        1  41.999763 -87.671324
# 6   (41.8018110912, -87.6305601801)        1  41.801811 -87.630560
# 7   (41.7796315359, -87.6608870173)        1  41.779632 -87.660887
# 8    (41.9186088912, -87.765574479)        1  41.918609 -87.765574
# 9    (41.8566845327, -87.708381958)        1  41.856685 -87.708382
# 10   (41.8800834614, -87.768199889)        1  41.880083 -87.768200
# 11  (41.7664308925, -87.6057478606)        1  41.766431 -87.605748
# 12  (41.9211033246, -87.6974518223)        1  41.921103 -87.697452
# 13   (41.778987189, -87.7088638153)        1  41.778987 -87.708864
# 14  (41.7079332906, -87.5683491228)        1  41.707933 -87.568349
# 15  (41.9795495131, -87.6928445094)        1  41.979550 -87.692845
# 16  (41.9032416531, -87.6433521393)        1  41.903242 -87.643352
# 17  (41.8629766244, -87.6569725149)        1  41.862977 -87.656973
# 18  (41.8373944311, -87.6464077068)        1  41.837394 -87.646408
# 19  (41.6914347795, -87.6685203937)        1  41.691435 -87.668520
# 20  (41.6927233639, -87.6045058667)        1  41.692723 -87.604506
# 21   (41.9660534171, -87.728114561)        1  41.966053 -87.728115
# 22   (41.9474004564, -87.651512018)        1  41.947400 -87.651512
#
#                       geometry
# 0   POINT (-87.62736 41.85837)
# 1   POINT (-87.64423 41.75214)
# 2   POINT (-87.70549 41.87358)
# 3   POINT (-87.76615 41.97409)
# 4   POINT (-87.62340 41.83070)
# 5   POINT (-87.67132 41.99976)
# 6   POINT (-87.63056 41.80181)
# 7   POINT (-87.66089 41.77963)
# 8   POINT (-87.76557 41.91861)
# 9   POINT (-87.70838 41.85668)
# 10  POINT (-87.76820 41.88008)
# 11  POINT (-87.60575 41.76643)
# 12  POINT (-87.69745 41.92110)
# 13  POINT (-87.70886 41.77899)
# 14  POINT (-87.56835 41.70793)
# 15  POINT (-87.69284 41.97955)
# 16  POINT (-87.64335 41.90324)
# 17  POINT (-87.65697 41.86298)
# 18  POINT (-87.64641 41.83739)
# 19  POINT (-87.66852 41.69143)
# 20  POINT (-87.60451 41.69272)
# 21  POINT (-87.72811 41.96605)
# 22  POINT (-87.65151 41.94740)

# %%
geo_df[geo_df['DISTRICT'] == '1']
# Out:
# C:\Users\chitr\anaconda3\envs\skmob\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   DISTRICT          ADDRESS     CITY STATE    ZIP  \
# 0        1  1718 S State St  Chicago    IL  60616
#
#                                              WEBSITE  \
# 0  http://home.chicagopolice.org/community/distri...
#
#                          LOCATION  user_id        lat       long  \
# 0  (41.8583725929, -87.627356171)        1  41.858373 -87.627356
#
#                      geometry
# 0  POINT (-87.62736 41.85837)

# %%
if pt.within(polys['geometry'][21]):
    t= polys['dist_num'][21]
    print(shape(pt))
    print(t)
    
    [a,b] =
# Out:
# C:\Users\chitr\anaconda3\envs\skmob\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   File "<ipython-input-32-6833432c031a>", line 6
#     [a,b] =
#             ^
# SyntaxError: invalid syntax

# %%
polys

# %%
from shapely.geometry import Point, Polygon

# %%
fp = "Chicago_PB.shp"

# %%
polys  = gpd.read_file(fp)

# %%
type(data['geometry'][21])

# %%
southern = polys[polys['dist_num']=='1']

# %%
type(pt)

# %%
southern['geometry']

# %%
poly = southern['geometry']

# %%
southern

# %%
poly.contains(pt)

# %%
PS_data

# %%
geometry =[Point (xy) for xy in zip(PS_data['long'],PS_data['lat'])]

# %%
geo_df = gpd.GeoDataFrame(PS_data,geometry = geometry)

# %%
fig, ax = plt.subplots()

polys.plot(ax=ax, facecolor='gray');
southern.plot(ax=ax, facecolor='red');
geo_df[geo_df['DISTRICT'] == '1'].plot(ax=ax, color='blue', markersize=5)

# %%
def dipatch_logic(polys, pt):
    
    for x in range(len(polys)-1): 
        if pt.within(polys['geometry'][x]): 
            t = 
    
    
    
    Resp_time = []
    orig_node = police
    #ser_time = 1200 # 20 mins service time
    my_array=[]
    arr_crime = [[0 for i in range(2)] for j in range(len(orig_node))]
    my_array = np.array(arr_crime).astype('int64')
    my_array[:,1]= orig_node 
    PC_stalk = [[0 for i in range(9)] for j in range(len(orig_node))] 
    for x in range(len(orig_node)):
        PC_stalk[x][0] =orig_node[x]
    for x in range(len(orig_node)):
        for y in range(3,9):
            PC_stalk[x][y]=[]
    columnIndex = 0   
    for j in range(len(Crime[0])):
        dest_node = Crime[1][j]
        Crime_node = Crime[1][j]
        Crime_time = Crime[0][j] ##chnage this
        Ser_time = Crime[2][j]
        if j !=len(Crime[0])-1:
            Crime_time_next = Crime[0][j+1]  ##change this
            
            
        for i in range(len(orig_node)):
            arr = ndk.shortest_path_length(Gs, orig_node[i], Crime_node, weight='time')
            my_array[i,0] = arr
            # Sort 2D numpy array by 1st Column
        sortedArr = my_array[my_array[:,columnIndex].argsort()]
        
        s = sortedArr[0][1]
        idx = np.argwhere(column(PC_stalk, 0) == s)[0][0] 

        if PC_stalk[idx][1] < NoOfOfficer:  # 
                PC_stalk[idx][1]= PC_stalk[idx][1]+1
                PC_stalk[idx][3].append(Crime_time)
                PC_stalk[idx][4].append(Crime_node)
                temp = ndk.shortest_path_length(Gs, PC_stalk[idx][0], Crime_node, weight='time')
                PC_stalk[idx][5].append(2*temp + Crime_time + Ser_time)
                Resp_time.append([temp,Crime_time])

        else : #--> 
       

    return Resp_node_F
